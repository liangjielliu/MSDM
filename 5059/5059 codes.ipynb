# %%
import pulp

# 所有厨房组合 Set（1-20）
sets = {
    1:  ["T2", "W2", "L4", "C2", "O4", "D2", "S2", "V2"],
    2:  ["T2", "W1", "L1", "C4", "O4", "D2", "S4", "V2"],
    3:  ["T1", "W3", "L2", "C1", "O1", "D1", "S3", "V3"],
    4:  ["T3", "W3", "L3", "C3", "O3", "D1", "S1", "V1"],
    5:  ["T4", "W4", "L1", "C1", "O2", "D1", "S2", "V1"],
    6:  ["T2", "W2", "L2", "C4", "O4", "D2", "S3", "V4"],
    7:  ["T1", "W3", "L4", "C3", "O2", "D1", "S1", "V1"],
    8:  ["T2", "W1", "L3", "C1", "O1", "D2", "S3", "V4"],
    9:  ["T2", "W1", "L2", "C3", "O2", "D2", "S2", "V2"],
    10: ["T1", "W1", "L1", "C1", "O3", "D1", "S4", "V3"],
    11: ["T3", "W1", "L3", "C3", "O1", "D1", "S1", "V3"],
    12: ["T2", "W2", "L1", "C2", "O2", "D2", "S4", "V2"],
    13: ["T4", "W4", "L3", "C3", "O1", "D1", "S2", "V3"],
    14: ["T4", "W4", "L4", "C1", "O3", None, "S1", "V1"],
    15: ["T3", "W3", "L1", "C1", "O1", None, "S3", "V3"],
    16: ["T3", "W3", "L4", "C1", "O3", None, "S2", "V1"],
    17: ["T1", "W4", "L2", "C3", "O3", None, "S4", "V3"],
    18: ["T3", "W3", "L3", "C2", "O4", None, "S1", "V2"],
    19: ["T3", "W4", "L4", "C4", "O4", None, "S2", "V4"],
    20: ["T3", "W3", "L1", "C1", "O2", None, "S3", "V4"],
}

# 风格分类集合
tiles = {"T1", "T2", "T3", "T4"}
wallpapers = {"W1", "W2", "W3", "W4"}
lights = {"L1", "L2", "L3", "L4"}
cabinets = {"C1", "C2", "C3", "C4"}
countertops = {"O1", "O2", "O3", "O4"}
sinks = {"S1", "S2", "S3", "S4"}
dishwashers = {"D1", "D2"}
ovens = {"V1", "V2", "V3", "V4"}

all_styles = set.union(tiles, wallpapers, lights, cabinets, countertops, sinks, dishwashers, ovens)

# 仓库风格数量限制
style_limits = {
    "T": 2,
    "W": 2,
    "L": 2,
    "C": 2,
    "O": 3,
    "S": 2,
    "D+V": 4
}

# 建立模型
model = pulp.LpProblem("最大化组合数", pulp.LpMaximize)

# 决策变量
y = {i: pulp.LpVariable(f"y_{i}", cat="Binary") for i in sets}
z = {s: pulp.LpVariable(f"z_{s}", cat="Binary") for s in all_styles}

# 目标函数：尽量多地组出组合
model += pulp.lpSum(y[i] for i in sets)

# 若选组合，其所有零件风格必须在库存中
for i in sets:
    for part in sets[i]:
        if part is not None:
            model += y[i] <= z[part]

# 限制每种风格的数量
model += pulp.lpSum(z[s] for s in tiles)       <= style_limits["T"]     # 瓷砖
model += pulp.lpSum(z[s] for s in wallpapers)  <= style_limits["W"]     # 墙纸
model += pulp.lpSum(z[s] for s in lights)      <= style_limits["L"]     # 灯具
model += pulp.lpSum(z[s] for s in cabinets)    <= style_limits["C"]     # 橱柜
model += pulp.lpSum(z[s] for s in countertops) <= style_limits["O"]     # 台面
model += pulp.lpSum(z[s] for s in sinks)       <= style_limits["S"]     # 水槽
model += pulp.lpSum(z[s] for s in dishwashers.union(ovens)) <= style_limits["D+V"]

# 求解模型
model.solve()

# 输出结果
print("可组装的厨房组合总数：", int(pulp.value(model.objective)))
print("组合编号如下：")
for i in sets:
    if pulp.value(y[i]) == 1:
        print(f"Set {i}: {sets[i]}")

print("\n仓库应存放的风格：")
for s in sorted(all_styles):
    if pulp.value(z[s]) == 1:
        print(s, end=" ")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/liuliangjie/Library/Python/3.9/lib/python/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/vt/qwvfy06n63q184jd56rxd3dh0000gn/T/bb7a4e95d3a34543a2c7edb07856e152-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/vt/qwvfy06n63q184jd56rxd3dh0000gn/T/bb7a4e95d3a34543a2c7edb07856e152-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 165 COLUMNS
# At line 622 RHS
# At line 783 BOUNDS
# At line 834 ENDATA
# Problem MODEL has 160 rows, 50 columns and 336 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 10 - 0.00 seconds
# Cgl0004I processed model has 160 rows, 50 columns (50 integer (50 of which binary)) and 336 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 50 integers unsatisfied sum - 25
# Cbc0038I Pass   1: suminf.    0.00000 (0) obj. 0 iterations 64
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 160 rows 50 columns, reduced to 160 rows 50 columns - 3 fixed gives 144, 47 - still too large
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of -1.89991
# Cbc0038I Pass   2: suminf.    2.29977 (22) obj. -1.89991 iterations 18
# Cbc0038I Pass   3: suminf.    2.04525 (24) obj. -1.89991 iterations 14
# Cbc0038I Pass   4: suminf.    5.66667 (17) obj. -5.33333 iterations 34
# Cbc0038I Pass   5: suminf.    5.66667 (17) obj. -5.33333 iterations 12
# Cbc0038I Pass   6: suminf.    1.83348 (5) obj. -1.89991 iterations 23
# Cbc0038I Solution found of -3
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 160 rows 50 columns, reduced to 160 rows 50 columns - 9 fixed gives 35, 19 - ok now
# Cbc0038I Full problem 160 rows 50 columns, reduced to 20 rows 14 columns
# Cbc0038I Mini branch and bound improved solution from -3 to -4 (0.02 seconds)
# Cbc0038I Round again with cutoff of -5.99992
# Cbc0038I Pass   7: suminf.   13.99964 (29) obj. -5.99992 iterations 12
# Cbc0038I Pass   8: suminf.   11.16648 (40) obj. -5.99992 iterations 13
# Cbc0038I Pass   9: suminf.   11.99984 (24) obj. -5.99992 iterations 35
# Cbc0038I Pass  10: suminf.   11.99956 (24) obj. -5.99992 iterations 17
# Cbc0038I Pass  11: suminf.    7.00008 (21) obj. -5.99992 iterations 22
# Cbc0038I Pass  12: suminf.    7.00000 (21) obj. -6 iterations 22
# Cbc0038I Pass  13: suminf.    7.66636 (46) obj. -5.99992 iterations 42
# Cbc0038I Pass  14: suminf.    7.66636 (46) obj. -5.99992 iterations 3
# Cbc0038I Pass  15: suminf.   14.24973 (42) obj. -5.99992 iterations 49
# Cbc0038I Pass  16: suminf.   11.99984 (40) obj. -5.99992 iterations 36
# Cbc0038I Pass  17: suminf.   11.31569 (39) obj. -5.99992 iterations 47
# Cbc0038I Pass  18: suminf.   10.26299 (39) obj. -5.99992 iterations 22
# Cbc0038I Pass  19: suminf.   13.00000 (39) obj. -7.33333 iterations 27
# Cbc0038I Pass  20: suminf.   12.59987 (41) obj. -5.99992 iterations 41
# Cbc0038I Pass  21: suminf.   12.29984 (41) obj. -5.99992 iterations 24
# Cbc0038I Pass  22: suminf.   12.44425 (45) obj. -5.99992 iterations 26
# Cbc0038I Pass  23: suminf.    9.79986 (49) obj. -5.99992 iterations 22
# Cbc0038I Pass  24: suminf.    8.42835 (49) obj. -5.99992 iterations 18
# Cbc0038I Pass  25: suminf.   13.99992 (42) obj. -5.99992 iterations 51
# Cbc0038I Pass  26: suminf.   13.19982 (44) obj. -5.99992 iterations 23
# Cbc0038I Pass  27: suminf.    7.00008 (21) obj. -5.99992 iterations 34
# Cbc0038I Pass  28: suminf.    7.00000 (21) obj. -6 iterations 24
# Cbc0038I Pass  29: suminf.   12.49983 (25) obj. -5.99992 iterations 32
# Cbc0038I Pass  30: suminf.   12.00000 (24) obj. -6 iterations 26
# Cbc0038I Pass  31: suminf.   11.99984 (24) obj. -5.99992 iterations 24
# Cbc0038I Pass  32: suminf.   12.00000 (24) obj. -6 iterations 22
# Cbc0038I Pass  33: suminf.   11.99936 (25) obj. -5.99992 iterations 35
# Cbc0038I Pass  34: suminf.    8.41646 (38) obj. -5.99992 iterations 13
# Cbc0038I Pass  35: suminf.   12.99932 (27) obj. -5.99992 iterations 29
# Cbc0038I Pass  36: suminf.    8.83315 (38) obj. -5.99992 iterations 20
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 160 rows 50 columns, reduced to 160 rows 50 columns - 9 fixed gives 35, 19 - ok now
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of -4 - took 0.02 seconds
# Cbc0012I Integer solution of -4 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0031I 14 added rows had average density of 31
# Cbc0013I At root node, 14 cuts changed objective from -10 to -7.4375434 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.020 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 1324 row cuts average 39.5 elements, 0 column cuts (0 active)  in 0.035 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.069 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.028 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 49 row cuts average 28.7 elements, 0 column cuts (0 active)  in 0.045 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -4 best solution, best possible -7.4375434 (0.43 seconds)
# Cbc0001I Search completed - best objective -4, took 7513 iterations and 10 nodes (0.53 seconds)
# Cbc0032I Strong branching done 254 times (7697 iterations), fathomed 0 nodes and fixed 9 variables
# Cbc0035I Maximum depth 3, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -10 to -7.43754
# Probing was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.020 seconds)
# Gomory was tried 142 times and created 1625 cuts of which 0 were active after adding rounds of cuts (0.046 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.069 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.028 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 100 times and created 49 cuts of which 0 were active after adding rounds of cuts (0.045 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4.00000000
# Enumerated nodes:               10
# Total iterations:               7513
# Time (CPU seconds):             0.53
# Time (Wallclock seconds):       0.54
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.53   (Wallclock seconds):       0.54
#
# 可组装的厨房组合总数： 4
# 组合编号如下：
# Set 4: ['T3', 'W3', 'L3', 'C3', 'O3', 'D1', 'S1', 'V1']
# Set 13: ['T4', 'W4', 'L3', 'C3', 'O1', 'D1', 'S2', 'V3']
# Set 14: ['T4', 'W4', 'L4', 'C1', 'O3', None, 'S1', 'V1']
# Set 16: ['T3', 'W3', 'L4', 'C1', 'O3', None, 'S2', 'V1']
#
# 仓库应存放的风格：
# C1 C3 D1 L3 L4 O1 O2 O3 S1 S2 T3 T4 V1 V3 V4 W3 W4

# %%
# 版本C：扩展版
# 限制：风格种类数（仓库容量）
style_limits = {
    "T": 2,
    "W": 2,
    "L": 2,
    "C": 2,
    "O": 3,
    "S": 2,
    "V": 3  # 烤箱限制 (c)
}

# 创建模型
model = pulp.LpProblem("最大组合数_版本C", pulp.LpMaximize)

# 决策变量
y = {i: pulp.LpVariable(f"y_{i}", cat="Binary") for i in sets}
z = {s: pulp.LpVariable(f"z_{s}", cat="Binary") for s in all_styles}

# 目标函数
model += pulp.lpSum(y[i] for i in sets)

# 如果选了组合i，其用到的风格必须在仓库中
for i in sets:
    for part in sets[i]:
        if part is not None:
            model += y[i] <= z[part]

# 限制每种风格的数量
model += pulp.lpSum(z[s] for s in tiles)       <= style_limits["T"]     # 瓷砖
model += pulp.lpSum(z[s] for s in wallpapers)  <= style_limits["W"]     # 墙纸
model += pulp.lpSum(z[s] for s in lights)      <= style_limits["L"]     # 灯具
model += pulp.lpSum(z[s] for s in cabinets)    <= style_limits["C"]     # 橱柜
model += pulp.lpSum(z[s] for s in countertops) <= style_limits["O"]     # 台面
model += pulp.lpSum(z[s] for s in sinks)       <= style_limits["S"]     # 水槽
model += pulp.lpSum(z[v] for v in ovens)       <= style_limits["V"]     # 烤箱

# 强制使用所有洗碗机
model += z["D1"] == 1
model += z["D2"] == 1

# 求解模型
model.solve()

# 输出结果
print("可组装的厨房组合总数（扩展后）:", int(pulp.value(model.objective)))
print("组合编号如下：")
for i in sets:
    if pulp.value(y[i]) == 1:
        print(f"Set {i}: {sets[i]}")

print("\n仓库应存放的风格：")
for s in sorted(all_styles):
    if pulp.value(z[s]) == 1:
        print(s, end=" ")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/liuliangjie/Library/Python/3.9/lib/python/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/vt/qwvfy06n63q184jd56rxd3dh0000gn/T/afa58996b53f44c38a4d47123ddf4e32-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/vt/qwvfy06n63q184jd56rxd3dh0000gn/T/afa58996b53f44c38a4d47123ddf4e32-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 167 COLUMNS
# At line 624 RHS
# At line 787 BOUNDS
# At line 838 ENDATA
# Problem MODEL has 162 rows, 50 columns and 336 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 10 - 0.00 seconds
# Cgl0004I processed model has 147 rows, 48 columns (48 integer (48 of which binary)) and 308 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 48 integers unsatisfied sum - 24
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 147 rows 48 columns, reduced to 147 rows 48 columns - too large
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I Round again with cutoff of -1.89991
# Cbc0038I Pass   1: suminf.    4.55978 (48) obj. -1.89991 iterations 15
# Cbc0038I Pass   2: suminf.    5.69973 (30) obj. -1.89991 iterations 42
# Cbc0038I Pass   3: suminf.    4.27480 (44) obj. -1.89991 iterations 23
# Cbc0038I Pass   4: suminf.   15.50000 (31) obj. -5.5 iterations 42
# Cbc0038I Pass   5: suminf.    4.17980 (44) obj. -1.89991 iterations 29
# Cbc0038I Pass   6: suminf.    5.38308 (34) obj. -1.89991 iterations 31
# Cbc0038I Pass   7: suminf.    4.27480 (44) obj. -1.89991 iterations 23
# Cbc0038I Pass   8: suminf.    2.69973 (20) obj. -1.89991 iterations 61
# Cbc0038I Pass   9: suminf.    1.94191 (38) obj. -1.89991 iterations 28
# Cbc0038I Pass  10: suminf.    0.40036 (4) obj. -1.89991 iterations 48
# Cbc0038I Solution found of -2
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 147 rows 48 columns, reduced to 147 rows 48 columns - 6 fixed gives 113, 42 - ok now
# Cbc0038I Full problem 147 rows 48 columns, reduced to 113 rows 42 columns
# Cbc0038I Mini branch and bound improved solution from -2 to -3 (0.03 seconds)
# Cbc0038I Round again with cutoff of -5.19992
# Cbc0038I Pass  11: suminf.   12.47981 (48) obj. -5.19992 iterations 0
# Cbc0038I Pass  12: suminf.   10.24430 (34) obj. -5.19992 iterations 57
# Cbc0038I Pass  13: suminf.    8.62089 (38) obj. -5.19992 iterations 18
# Cbc0038I Pass  14: suminf.   10.19985 (34) obj. -5.19992 iterations 38
# Cbc0038I Pass  15: suminf.    8.62089 (38) obj. -5.19992 iterations 26
# Cbc0038I Pass  16: suminf.    6.91403 (43) obj. -5.19992 iterations 31
# Cbc0038I Pass  17: suminf.    6.91403 (43) obj. -5.19992 iterations 13
# Cbc0038I Pass  18: suminf.   11.34106 (36) obj. -5.19992 iterations 12
# Cbc0038I Pass  19: suminf.   10.13984 (39) obj. -5.19992 iterations 16
# Cbc0038I Pass  20: suminf.   11.37482 (35) obj. -5.19992 iterations 18
# Cbc0038I Pass  21: suminf.   13.97486 (29) obj. -5.19992 iterations 41
# Cbc0038I Pass  22: suminf.   10.65984 (41) obj. -5.19992 iterations 41
# Cbc0038I Pass  23: suminf.   12.33333 (37) obj. -7 iterations 37
# Cbc0038I Pass  24: suminf.    8.39984 (38) obj. -5.19992 iterations 16
# Cbc0038I Pass  25: suminf.    9.68953 (38) obj. -5.19992 iterations 34
# Cbc0038I Pass  26: suminf.    8.62089 (38) obj. -5.19992 iterations 25
# Cbc0038I Pass  27: suminf.    8.66667 (26) obj. -5.33333 iterations 42
# Cbc0038I Pass  28: suminf.    8.33333 (25) obj. -5.33333 iterations 18
# Cbc0038I Pass  29: suminf.    7.66667 (23) obj. -5.33333 iterations 2
# Cbc0038I Pass  30: suminf.    4.39971 (44) obj. -5.19992 iterations 34
# Cbc0038I Pass  31: suminf.    4.39971 (37) obj. -5.19992 iterations 14
# Cbc0038I Pass  32: suminf.    7.03982 (33) obj. -5.19992 iterations 32
# Cbc0038I Pass  33: suminf.    6.57761 (37) obj. -5.19992 iterations 20
# Cbc0038I Pass  34: suminf.   11.33333 (34) obj. -7 iterations 31
# Cbc0038I Pass  35: suminf.    7.28871 (37) obj. -5.19992 iterations 35
# Cbc0038I Pass  36: suminf.    7.28871 (37) obj. -5.19992 iterations 10
# Cbc0038I Pass  37: suminf.    9.27977 (29) obj. -5.19992 iterations 28
# Cbc0038I Pass  38: suminf.    6.57761 (37) obj. -5.19992 iterations 19
# Cbc0038I Pass  39: suminf.    8.63978 (27) obj. -5.19992 iterations 23
# Cbc0038I Pass  40: suminf.    8.15946 (27) obj. -5.19992 iterations 36
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 147 rows 48 columns, reduced to 147 rows 48 columns - 8 fixed gives 102, 40 - ok now
# Cbc0038I Full problem 147 rows 48 columns, reduced to 102 rows 40 columns
# Cbc0038I Mini branch and bound did not improve solution (0.04 seconds)
# Cbc0038I After 0.04 seconds - Feasibility pump exiting with objective of -3 - took 0.03 seconds
# Cbc0012I Integer solution of -3 found by feasibility pump after 0 iterations and 0 nodes (0.04 seconds)
# Cbc0012I Integer solution of -4 found by DiveCoefficient after 0 iterations and 0 nodes (0.04 seconds)
# Cbc0031I 11 added rows had average density of 25.818182
# Cbc0013I At root node, 11 cuts changed objective from -10 to -7.5731247 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.018 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 1051 row cuts average 39.5 elements, 0 column cuts (0 active)  in 0.032 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.060 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.003 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.024 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 18 row cuts average 24.7 elements, 0 column cuts (0 active)  in 0.039 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, -4 best solution, best possible -7.5731247 (0.38 seconds)
# Cbc0004I Integer solution of -5 found after 5270 iterations and 2 nodes (0.40 seconds)
# Cbc0001I Search completed - best objective -5, took 5982 iterations and 5 nodes (0.44 seconds)
# Cbc0032I Strong branching done 174 times (5167 iterations), fathomed 1 nodes and fixed 1 variables
# Cbc0035I Maximum depth 1, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -10 to -7.57312
# Probing was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.018 seconds)
# Gomory was tried 125 times and created 1261 cuts of which 0 were active after adding rounds of cuts (0.038 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.060 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.003 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.024 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 100 times and created 18 cuts of which 0 were active after adding rounds of cuts (0.039 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
#
# Result - Optimal solution found
#
# Objective value:                5.00000000
# Enumerated nodes:               5
# Total iterations:               5982
# Time (CPU seconds):             0.44
# Time (Wallclock seconds):       0.45
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.44   (Wallclock seconds):       0.45
#
# 可组装的厨房组合总数（扩展后）: 5
# 组合编号如下：
# Set 4: ['T3', 'W3', 'L3', 'C3', 'O3', 'D1', 'S1', 'V1']
# Set 8: ['T2', 'W1', 'L3', 'C1', 'O1', 'D2', 'S3', 'V4']
# Set 11: ['T3', 'W1', 'L3', 'C3', 'O1', 'D1', 'S1', 'V3']
# Set 15: ['T3', 'W3', 'L1', 'C1', 'O1', None, 'S3', 'V3']
# Set 20: ['T3', 'W3', 'L1', 'C1', 'O2', None, 'S3', 'V4']
#
# 仓库应存放的风格：
# C1 C3 D1 D2 L1 L3 O1 O2 O3 S1 S3 T2 T3 V1 V3 V4 W1 W3

# %%
# 版本D：扩容版
# 限制风格种类（不限制的不写）
style_limits = {
    "T": 2,  # 瓷砖
    "W": 2,  # 墙纸
    "L": 3,  # 灯具
    "C": 3,  # 橱柜
    "V": 3   # 烤箱
}

# 模型
model = pulp.LpProblem("最大组合数_版本D", pulp.LpMaximize)

# 决策变量
y = {i: pulp.LpVariable(f"y_{i}", cat="Binary") for i in sets}
z = {s: pulp.LpVariable(f"z_{s}", cat="Binary") for s in all_styles}

# 目标函数
model += pulp.lpSum(y[i] for i in sets)

# 组合可行性约束：用到的风格必须在仓库中
for i in sets:
    for part in sets[i]:
        if part is not None:
            model += y[i] <= z[part]

# 限制每种风格的数量
model += pulp.lpSum(z[s] for s in tiles)       <= style_limits["T"]     # 瓷砖
model += pulp.lpSum(z[s] for s in wallpapers)  <= style_limits["W"]     # 墙纸
model += pulp.lpSum(z[s] for s in lights)      <= style_limits["L"]     # 灯具
model += pulp.lpSum(z[s] for s in cabinets)    <= style_limits["C"]     # 橱柜
model += pulp.lpSum(z[v] for v in ovens)       <= style_limits["V"]     # 烤箱

# 强制使用所有洗碗机
model += z["D1"] == 1
model += z["D2"] == 1

# 求解
model.solve()

# 输出结果
print("可组装的厨房组合总数（扩容版本）:", int(pulp.value(model.objective)))
print("组合编号如下：")
for i in sets:
    if pulp.value(y[i]) == 1:
        print(f"Set {i}: {sets[i]}")

print("\n仓库应存放的风格：")
for s in sorted(all_styles):
    if pulp.value(z[s]) == 1:
        print(s, end=" ")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /Users/liuliangjie/Library/Python/3.9/lib/python/site-packages/pulp/apis/../solverdir/cbc/osx/i64/cbc /var/folders/vt/qwvfy06n63q184jd56rxd3dh0000gn/T/d8a1db4459d2494b86400b2c50f24886-pulp.mps -max -timeMode elapsed -branch -printingOptions all -solution /var/folders/vt/qwvfy06n63q184jd56rxd3dh0000gn/T/d8a1db4459d2494b86400b2c50f24886-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 165 COLUMNS
# At line 614 RHS
# At line 775 BOUNDS
# At line 826 ENDATA
# Problem MODEL has 160 rows, 50 columns and 328 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 10 - 0.00 seconds
# Cgl0004I processed model has 105 rows, 40 columns (40 integer (40 of which binary)) and 220 elements
# Cutoff increment increased from 1e-05 to 0.9999
# Cbc0038I Initial state - 40 integers unsatisfied sum - 20
# Cbc0038I Solution found of 0
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 105 rows 40 columns, reduced to 105 rows 40 columns
# Cbc0038I Mini branch and bound improved solution from 0 to -8 (0.02 seconds)
# Cbc0038I Round again with cutoff of -9.09991
# Cbc0038I Pass   1: suminf.   18.19982 (40) obj. -9.09991 iterations 15
# Cbc0038I Pass   2: suminf.    9.34923 (39) obj. -9.09991 iterations 43
# Cbc0038I Pass   3: suminf.    7.76628 (38) obj. -9.09991 iterations 10
# Cbc0038I Pass   4: suminf.    7.76628 (38) obj. -9.09991 iterations 1
# Cbc0038I Pass   5: suminf.   10.47435 (35) obj. -9.09991 iterations 21
# Cbc0038I Pass   6: suminf.    9.49955 (29) obj. -9.09991 iterations 10
# Cbc0038I Pass   7: suminf.    9.90009 (29) obj. -9.09991 iterations 13
# Cbc0038I Pass   8: suminf.    9.62500 (32) obj. -9.375 iterations 20
# Cbc0038I Pass   9: suminf.    9.49955 (38) obj. -9.09991 iterations 23
# Cbc0038I Pass  10: suminf.    7.76628 (38) obj. -9.09991 iterations 10
# Cbc0038I Pass  11: suminf.    7.76628 (38) obj. -9.09991 iterations 3
# Cbc0038I Pass  12: suminf.   17.09991 (35) obj. -9.09991 iterations 45
# Cbc0038I Pass  13: suminf.   16.37984 (36) obj. -9.09991 iterations 25
# Cbc0038I Pass  14: suminf.    9.34924 (34) obj. -9.09991 iterations 29
# Cbc0038I Pass  15: suminf.    7.76628 (38) obj. -9.09991 iterations 4
# Cbc0038I Pass  16: suminf.    7.76628 (38) obj. -9.09991 iterations 2
# Cbc0038I Pass  17: suminf.   10.47435 (35) obj. -9.09991 iterations 18
# Cbc0038I Pass  18: suminf.    9.49955 (29) obj. -9.09991 iterations 10
# Cbc0038I Pass  19: suminf.    9.90009 (29) obj. -9.09991 iterations 16
# Cbc0038I Pass  20: suminf.    9.62500 (32) obj. -9.375 iterations 23
# Cbc0038I Pass  21: suminf.   10.61641 (38) obj. -9.09991 iterations 21
# Cbc0038I Pass  22: suminf.   10.61641 (40) obj. -9.09991 iterations 4
# Cbc0038I Pass  23: suminf.   16.09991 (33) obj. -9.09991 iterations 27
# Cbc0038I Pass  24: suminf.   15.46985 (34) obj. -9.09991 iterations 24
# Cbc0038I Pass  25: suminf.    7.76628 (38) obj. -9.09991 iterations 23
# Cbc0038I Pass  26: suminf.    7.76628 (38) obj. -9.09991 iterations 4
# Cbc0038I Pass  27: suminf.    9.89955 (31) obj. -9.09991 iterations 13
# Cbc0038I Pass  28: suminf.    9.49955 (29) obj. -9.09991 iterations 7
# Cbc0038I Pass  29: suminf.    9.90009 (29) obj. -9.09991 iterations 17
# Cbc0038I Pass  30: suminf.    9.62500 (32) obj. -9.375 iterations 15
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 0 continuous
# Cbc0038I Full problem 105 rows 40 columns, reduced to 105 rows 40 columns
# Cbc0038I Mini branch and bound did not improve solution (0.03 seconds)
# Cbc0038I After 0.03 seconds - Feasibility pump exiting with objective of -8 - took 0.03 seconds
# Cbc0012I Integer solution of -8 found by feasibility pump after 0 iterations and 0 nodes (0.03 seconds)
# Cbc0031I 9 added rows had average density of 18.888889
# Cbc0013I At root node, 19 cuts changed objective from -10 to -8.9089572 in 8 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 38 row cuts average 23.1 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 43 row cuts average 22.6 elements, 0 column cuts (0 active)  in 0.009 seconds - new frequency is -100
# Cbc0001I Search completed - best objective -8, took 114 iterations and 0 nodes (0.06 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from -10 to -8.90896
# Probing was tried 8 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 8 times and created 38 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 8 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Clique was tried 8 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 8 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 8 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 8 times and created 43 cuts of which 0 were active after adding rounds of cuts (0.009 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                8.00000000
# Enumerated nodes:               0
# Total iterations:               114
# Time (CPU seconds):             0.06
# Time (Wallclock seconds):       0.06
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.06   (Wallclock seconds):       0.06
#
# 可组装的厨房组合总数（扩容版本）: 8
# 组合编号如下：
# Set 4: ['T3', 'W3', 'L3', 'C3', 'O3', 'D1', 'S1', 'V1']
# Set 5: ['T4', 'W4', 'L1', 'C1', 'O2', 'D1', 'S2', 'V1']
# Set 13: ['T4', 'W4', 'L3', 'C3', 'O1', 'D1', 'S2', 'V3']
# Set 14: ['T4', 'W4', 'L4', 'C1', 'O3', None, 'S1', 'V1']
# Set 15: ['T3', 'W3', 'L1', 'C1', 'O1', None, 'S3', 'V3']
# Set 16: ['T3', 'W3', 'L4', 'C1', 'O3', None, 'S2', 'V1']
# Set 19: ['T3', 'W4', 'L4', 'C4', 'O4', None, 'S2', 'V4']
# Set 20: ['T3', 'W3', 'L1', 'C1', 'O2', None, 'S3', 'V4']
#
# 仓库应存放的风格：
# C1 C3 C4 D1 D2 L1 L3 L4 O1 O2 O3 O4 S1 S2 S3 S4 T3 T4 V1 V3 V4 W3 W4
